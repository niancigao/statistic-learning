# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## 1
# For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# $MSE(T) = E(T- \theta )^2$
# $= var(T) + (bias(T))^2$<br>
#
# $bias(T) = E(T) - \theta$

# %% [markdown]
# (a) The sample size n is extremely large, and the number of predictors p is small.

# %% [markdown]
# - **非常大的樣本，很少的預測變量 : 好**
#
# n越大，資訊越多，降低偏差，擬合的越好，p小，變數少，噪音的影響越不明顯

# %% [markdown]
# (b) The number of predictors p is extremely large, and the number of observations n is small.

# %% [markdown]
# - **大量的預測變量，小樣本 : 糟**
#
# p大，n小，可能不重要變數造成噪音越明顯，使偏差、方差變大

# %% [markdown]
# (c) The relationship between the predictors and response is highly non-linear.

# %% [markdown]
# - **高度非線性關係 : 好**
#
# 現實上多是非線性的狀況，線性模型容易使模型受到限制

# %% [markdown]
# (d) The variance of the error terms, i.e. σ2 = Var(ϵ), is extremely high.

# %% [markdown]
# - **極高的方差 : 糟**
#
# MSE指標越小越好，高方差在偏差固定下明顯顯示模型更糟糕
#
# 由於方差非常高，因此更靈活的模型將更適合噪聲，因此很可能過擬合。<br>不太靈活的模型將更有可能仍然捕獲模型的基本“特徵”，而不會拾取由噪聲引起的無關特徵。

# %% [markdown]
# ## 4
# You will now think of some real-life applications for statistical learning.

# %% [markdown]
# (a) Describe three real-life applications in which classification might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.

# %% [markdown]
# 1. 垃圾郵件分類器
# ```
# response : 分出'垃圾郵件'和'非垃圾郵件'
# predictors : 是否為聯絡人，信件內容，類似的電子郵件是否已被其他用戶標記為垃圾郵件等
# goal : 預測，因為最重要的任務是能夠準確地預測未來的電子郵件是垃圾郵件還是非垃圾郵件
# ```
# 2. 醫療診斷
# ```
# response : 分出'得病'和'沒病'
# predictors : 家族病史、特定基因、生活習慣等
# goal : 推理，除了預測某人是否得病，我們有興趣了解和研究不同的因素並發現它們之間的關係
# ```
# 3. 保單
# ```
# response : 分出'提出索賠'和'不索賠'
# predictors : 疾病、職業、年齡等
# goal : 推理，除了預測，我們有興趣了解和研究不同的因素並決定該如何定價
# ```

# %% [markdown]
# (b) Describe three real-life applications in which regression might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.

# %% [markdown]
# 1. 房價
# ```
# response : 估價
# predictors : 地點、交通、治安、福利等
# goal : 預測，最重要的任務是至少得先買得起一棟房子
# ```
# 2. 成績
# ```
# response : 分數
# predictors : 學校、讀書時間、家庭等
# goal : 預測，最重要的是拿到好成績
# ```
# 3. 地震
# ```
# response : 何時發生
# predictors : 板塊活躍狀況、火山活動、地函物質相變化等
# goal : 推斷，除了預測，我們有興趣了解和研究不同的因素並預防災害，寄出通知
# ```

# %% [markdown]
# (c) Describe three real-life applications in which cluster analysis might be useful.

# %% [markdown]
# 1. 客戶分群，不同客群給予不同行銷手法
# 2. 利用 DNA，對同一疾病不同等級的患者分類
# 3. 網際網路應用上，聚類分析被用來在網上進行文檔歸類來修覆信息

# %% [markdown]
# ## 8.
#
# This exercise relates to the **College** data set, which can be found in the ﬁle **College.csv** on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are
#
# - **Private** : Public/private indicator (公/私立)
# - **Apps** : Number of applications received (收到的申請數量)
# - **Accept** : Number of applicants accepted (接受的申請人數)
# - **Enroll** : Number of new students enrolled (新入學人數)
# - **Top10perc** : New students from top 10 % of high school class
# - **Top25perc** : New students from top 25 % of high school class
# - **F.Undergrad** : Number of full-time undergraduates
# - **P.Undergrad** : Number of part-time undergraduates
# - **Outstate** : Out-of-state tuition (州外學費)
# - **Room.Board** : Room and board costs (食宿費用)
# - **Books** : Estimated book costs
# - **Personal** : Estimated personal spending
# - **PhD** : Percent of faculty with Ph.D.’s (擁有博士學位的教師百分比)
# - **Terminal** : Percent of faculty with terminal degree (擁有終端學位的教師百分比)
# - **S.F.Ratio** : Student/faculty ratio
# - **perc.alumni** : Percent of alumni who donate (捐贈校友的百分比)
# - **Expend** : Instructional expenditure per student (每名學生的教學支出)
# - **Grad.Rate** : Graduation rate
#
# Before reading the data into <span style="color: #922B21;">Python</span>, it can be viewed in Excel or a text
# editor.
#
# (a) Use the <span style="color: #922B21;">pd.read_csv()</span>
#  function to read the data into python. Call the loaded data <span style="color: #922B21;">college</span>. Make sure that you have the directory set to the correct location for the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
college = pd.read_csv(r"C:\Users\user\Desktop\統計探勘功課\College.csv")
college

# 路徑字串開頭要寫 r & 檔案名稱.csv                         
# r :為了不讓 \ 被讀成特殊字元 EX: \n
# 指定欄位 id 為索引 (取代原本 0.1...957918的位置)
# ,index_col='id'
# college.index.name = 'Names'
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# (b) Look at the data using the <span style="color: #922B21;">college.head()</span> function. You should notice
# that the first column is just the name of each university.We don’t
# really want <span style="color: #922B21;">Python</span> to treat this as data. However, it may be handy to have these names for later. Try the following commands:
#
# ---
# > college.index = college["Unnamed: 0"]<br>
# > college.index.name = 'Names'<br>
# > college.head()<br>
# ---
#
# You should see that there is now a <span style="color: #922B21;">index</span> column with the name of each university recorded. This means that <span style="color: #922B21;">python</span> has given
# each row a name corresponding to the appropriate university. <span style="color: #922B21;">Python</span>
# will not try to perform calculations on the row names. However,
# we still need to eliminate the first column in the data where the
# names are stored. Try
#
# ---
# > college = college.drop("Unnamed: 0", axis=1)<br>
# > college.head()
# ---
#
# Now you should see that the first data column is <span style="color: #922B21;">Private</span>. Note
# that another column labeled <span style="color: #922B21;">index</span> now appears before the
# <span style="color: #922B21;">Private</span> column. However, this is not a data column but rather the name that <span style="color: #922B21;">Python</span> is giving to each row.

# %%
college.index = college["Unnamed: 0"]
college.index.name = 'Names'
college.head()

# college = college.set_index("Unnamed: 0") 
# The default option 'drop=True', deletes the column
# Out:
#                                                 Unnamed: 0 Private  Apps  \
# Names
# Abilene Christian University  Abilene Christian University     Yes  1660
# Adelphi University                      Adelphi University     Yes  2186
# Adrian College                              Adrian College     Yes  1428
# Agnes Scott College                    Agnes Scott College     Yes   417
# Alaska Pacific University        Alaska Pacific University     Yes   193
#
#                               Accept  Enroll  Top10perc  Top25perc  \
# Names
# Abilene Christian University    1232     721         23         52
# Adelphi University              1924     512         16         29
# Adrian College                  1097     336         22         50
# Agnes Scott College              349     137         60         89
# Alaska Pacific University        146      55         16         44
#
#                               F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# Names
# ...

# %%
college = college.drop("Unnamed: 0", axis=1)
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Names
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Names
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# (c)
#
# i. Use the <span style="color: #922B21;">college.describe()</span> function to produce a numerical summary of the variables in the data set.

# %%
college.describe(include='all')

# 如果沒有 'all' 選項，則不會顯示分類
# Out:
#        Private          Apps        Accept       Enroll   Top10perc  \
# count      777    777.000000    777.000000   777.000000  777.000000
# unique       2           NaN           NaN          NaN         NaN
# top        Yes           NaN           NaN          NaN         NaN
# freq       565           NaN           NaN          NaN         NaN
# mean       NaN   3001.638353   2018.804376   779.972973   27.558559
# std        NaN   3870.201484   2451.113971   929.176190   17.640364
# min        NaN     81.000000     72.000000    35.000000    1.000000
# 25%        NaN    776.000000    604.000000   242.000000   15.000000
# 50%        NaN   1558.000000   1110.000000   434.000000   23.000000
# 75%        NaN   3624.000000   2424.000000   902.000000   35.000000
# max        NaN  48094.000000  26330.000000  6392.000000   96.000000
#
#          Top25perc   F.Undergrad   P.Undergrad      Outstate   Room.Board  \
# count   777.000000    777.000000    777.000000    777.000000   777.000000
# ...

# %%
college.describe(include=['number'])
# or college.describe(include=[np.number])
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college.describe(include=['object'])
# or college.describe(include=['O'])
# Out:
#        Private
# count      777
# unique       2
# top        Yes
# freq       565

# %% [markdown]
# ii. Use the <span style="color: #922B21;">sns.pairplot()</span> function to produce a scatterplot matrix of the first ten columns or variables of the data. Recall that you can reference the first ten columns of a matrix <span style="color: #922B21;">A</span> using
# <span style="color: #922B21;">A.iloc[:,0:10]</span>.

# %% [markdown]
# [Python可视化 | Seaborn5分钟入门(七)——pairplot](https://zhuanlan.zhihu.com/p/98729226)

# %%
sns.pairplot(college.iloc[:,0:11],kind="reg",diag_kind="kde",hue='Private') 

#  pairplot 忽略分類變量
# 单独用 vars 参数选择"萼片长 "和"花瓣长"两种属性
# sns.pairplot(data,vars=["萼片长","花瓣长"])

# %%
college.iloc[:,1:11].shape
# Out:
# (777, 10)

# %%
# 與 R 不同，seaborn 不會對分類與數值進行配對

g = sns.PairGrid(college, vars=college.iloc[:,1:11], hue='Private')
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(plt.scatter, s=3)
g.fig.set_size_inches(12, 12)

# %% [markdown]
# iii. Use the <span style="color: #922B21;">sns.boxplot()</span> function to produce side-by-side boxplots of <span style="color: #922B21;">Outstate</span> versus <span style="color: #922B21;">Private</span>.

# %% [markdown]
# [seaborn.boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
sns.boxplot(x='Private', y='Outstate', data=college)
# Out:
# <AxesSubplot:xlabel='Private', ylabel='Outstate'>

# %% [markdown]
# iv. Create a new qualitative variable, called <span style="color: #922B21;">Elite</span>, by binning the <span style="color: #922B21;">Top10perc</span> variable. We are going to divide universities
# into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50 %.
#
# ---
# > college['Elite'] = np.where(college['Top10perc'] > 50,'Yes','No')<br>
# > college.head()
# ---
#
# Use the <span style="color: #922B21;">college['Elite'].value_counts()</span> function to see how many elite universities there are. Now use the <span style="color: #922B21;">sns.boxplot()</span> function to produce side-by-side boxplots of <span style="color: #922B21;">Outstate</span> versus <span style="color: #922B21;">Elite</span>.

# %%
college['Elite'] = np.where(college['Top10perc'] > 50,'Yes','No')
college.head()

# college.loc[college['Top10perc']>50, 'Elite'] = 'Yes'
# college['Elite'] = college['Elite'].fillna('No')
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Names
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Names
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
sns.boxplot(x='Elite', y='Outstate', data=college)
# Out:
# <AxesSubplot:xlabel='Elite', ylabel='Outstate'>

# %% [markdown]
# v. Use the <span style="color: #922B21;">sns.histplot()</span> function to produce some histograms with differing numbers of bins for a few of the quantitative variables.

# %%
# Bins creation
college['PhD'] = pd.cut(college['PhD'], 3, labels=['Low', 'Medium', 'High'])
college['Grad.Rate'] = pd.cut(college['Grad.Rate'], 5, labels=['Very low', 'Low', 'Medium', 'High', 'Very high'])
college['Books'] = pd.cut(college['Books'], 2, labels=['Low', 'High'])
college['Enroll'] = pd.cut(college['Enroll'], 4, labels=['Very low', 'Low', 'High', 'Very high'])

# %%
college
# Out:
#                                Private   Apps  Accept    Enroll  Top10perc  \
# Names
# Abilene Christian University       Yes   1660    1232  Very low         23
# Adelphi University                 Yes   2186    1924  Very low         16
# Adrian College                     Yes   1428    1097  Very low         22
# Agnes Scott College                Yes    417     349  Very low         60
# Alaska Pacific University          Yes    193     146  Very low         16
# ...                                ...    ...     ...       ...        ...
# Worcester State College             No   2197    1515  Very low          4
# Xavier University                  Yes   1959    1805  Very low         24
# Xavier University of Louisiana     Yes   2097    1915  Very low         34
# Yale University                    Yes  10705    2453  Very low         95
# York College of Pennsylvania       Yes   2989    1855  Very low         28
#
# ...

# %%
college['Grad.Rate'].value_counts()
# Out:
# Medium       340
# High         213
# Low          179
# Very high     26
# Very low      19
# Name: Grad.Rate, dtype: int64

# %%
fig = plt.figure()  # To add space between subplots

plt.subplot(221)
college['PhD'].value_counts().plot(kind='bar', title = 'Private');
plt.subplot(222)
college['Grad.Rate'].value_counts().plot(kind='bar', title = 'Grad.Rate');
plt.subplot(223)
college['Books'].value_counts().plot(kind='bar', title = 'Books');
plt.subplot(224)
college['Enroll'].value_counts().plot(kind='bar', title = 'Enroll');

fig.subplots_adjust(hspace=1) # To add space between subplots

# %% [markdown]
# vi. Continue exploring the data, and provide a brief summary of what you discover.

# %%
college2 = pd.read_csv(r"C:\Users\user\Desktop\統計探勘功課\College.csv",index_col='Unnamed: 0')

# 指定欄位 id 為索引 (取代原本 0.1...957918的位置)
# ,index_col='id'
# college.index.name = 'Names'

# %% [markdown]
# ```python
# # correlation matrix
#
# corrmat_ = college2.iloc[:,0:19].corr()      # 'list' object has no attribute 'corr'
#
# f, ax = plt.subplots(figsize=(12, 9))
# sns.heatmap(corrmat_, square=True,annot=True,cmap = 'YlGnBu_r')
#
# # corrmat_
# ```

# %%
college2.dtypes
# Out:
# Private         object
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %%
college2['Private'] = college2['Private'].astype('category')

# 注意：astype不是原地操作，需要重新赋值
# 要轉 'category'

# %%
cat_columns = college2.select_dtypes(['category']).columns
print(cat_columns)
# Out:
# Index(['Private'], dtype='object')

# %%
college2[cat_columns] = college2[cat_columns].apply(lambda x: x.cat.codes)

# %%
# college2

# %%
# correlation matrix

corrmat_ = college2.iloc[:,0:19].corr()      # 'list' object has no attribute 'corr'

f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat_, square=True,annot=True,cmap = 'YlGnBu_r')

# corrmat_
# Out:
# <AxesSubplot:>

# %% [markdown]
# 關係 :
#
# 負相關:私立學校&入學數<br>
# 正相關:擁有終端學位的教師百分比&擁有博士學位的教師百分比
#
# 等等

# %% [markdown]
# [使用 Python 進行全面的數據探索](https://www.kaggle.com/code/pmarcelino/comprehensive-data-exploration-with-python)

# %% [markdown]
# # 9
# This exercise involves the **Auto** data set studied in the lab. Make sure
# that the missing values have been removed from the data.

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\統計探勘功課\Auto.csv",index_col='Unnamed: 0')

df

# 指定欄位 id 為索引 (取代原本 0.1...957918的位置)
# ,index_col='id'
# college.index.name = 'Names'
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1    18.0          8         307.0         130    3504          12.0    70
# 2    15.0          8         350.0         165    3693          11.5    70
# 3    18.0          8         318.0         150    3436          11.0    70
# 4    16.0          8         304.0         150    3433          12.0    70
# 5    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0          86    2790          15.6    82
# 394  44.0          4          97.0          52    2130          24.6    82
# 395  32.0          4         135.0          84    2295          11.6    82
# 396  28.0          4         120.0          79    2625          18.6    82
# 397  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
df.isna().sum().sum()   # 全部缺失值
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 1 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
# df.horsepower.unique()

# %%
# df = df[df.horsepower != '?'].copy() # [1]           # 刪缺失值
# df['horsepower']=pd.to_numeric(df['horsepower'])

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
# 定量

quantitative = df.select_dtypes(include=['number']).columns
quantitative
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin'],
#       dtype='object')

# %%
# 定性

qualitative = df.select_dtypes(exclude=['number']).columns
qualitative
# Out:
# Index(['name'], dtype='object')

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer
# this using the Auto.describe() function.

# %%
a = df.describe()
a.loc['range'] = a.loc['max'] - a.loc['min']
a.loc['range']
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# Name: range, dtype: float64

# %%
a
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
# range   37.600000    5.000000    387.000000  184.000000  3527.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# ...

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative
# predictor?

# %%
type(['mean','std','range'])
# Out:
# list

# %%
a.loc[['mean','std','range']]
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# mean   23.445918   5.471939    194.411990  104.469388  2977.584184
# std     7.805007   1.705783    104.644004   38.491160   849.402560
# range  37.600000   5.000000    387.000000  184.000000  3527.000000
#
#        acceleration       year    origin
# mean      15.541327  75.979592  1.576531
# std        2.758864   3.683737  0.805518
# range     16.800000  12.000000  2.000000

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %% [markdown]
# [【pandas】删除满足条件元素所在的行](https://blog.csdn.net/u014636245/article/details/104202889)

# %%
df.index[10:85] == df[10:85].index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
# df[10:85].index

# %%
df_b = df.drop(df.index[10:85])

b = df_b.describe()
b.loc['range'] = b.loc['max'] - b.loc['min']
b.loc[['mean','std', 'range']]
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# mean   24.374763   5.381703    187.880126  101.003155  2938.854890
# std     7.872565   1.658135    100.169973   36.003208   811.640668
# range  35.600000   5.000000    387.000000  184.000000  3348.000000
#
#        acceleration       year    origin
# mean      15.704101  77.123028  1.599369
# std        2.719913   3.127158  0.819308
# range     16.300000  12.000000  2.000000

# %% [markdown]
# (e) Using the full data set, investigate (調查) the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your findings.

# %%
sns.pairplot(df.iloc[:,0:9],kind="reg",diag_kind="kde",hue='cylinders')  # 氣缸
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - 汽缸的數量的多寡跟各變數大部分都有明顯區別(橘、紫明顯分群)
# - 馬力&重量、馬力&排量、排量&重量等，皆有線性趨勢

# %%
g = sns.PairGrid(df, size=2)
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.fig.set_size_inches(12, 12)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:1152: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# - “加速度”的直方圖類似於正態分佈

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (耗油量) (<span style="color: #922B21;">mpg</span>) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting <span style="color: #922B21;">mpg</span>? Justify your
# answer.

# %%
# correlation matrix

corrmat_2 = df.iloc[:,0:8].corr()      # 'list' object has no attribute 'corr'

f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat_2, square=True,annot=True,cmap = 'YlGnBu_r')

# corrmat_2
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 重量、馬力、排量、汽缸數。從熱圖可以看出
