# %% [markdown]
# # Assignment 4

# %% [markdown]
# #### Student ID: B082040005
#
# #### Name: 高念慈

# %% [markdown]
# 部分習題需要寫數學式。
#
# 若不想用打的，可用手寫後，進行拍照或掃描，並使用以下指令引入圖片。
#
# 請確認圖片清晰程度為可辨識。
#
# `![title](test.png)`

# %% [markdown]
# # 4
# When the number of features $p$ is large, there tends to be a deterioration (惡化)
# in the performance of KNN and other local approaches that perform prediction using only observations that are near the test observation for which a prediction must be made. This phenomenon is known as the curse of dimensionality (維度災難), and it ties into (聯繫到) the fact that parametric approaches often perform poorly when $p$ is large. We will now investigate (研究) this curse (詛咒).

# %% [markdown]
# (a) Suppose that we have a set of observations, each with measurements on $p = 1$ feature, $X$. We assume that $X$ is uniformly (evenly) distributed on $[0, 1]$. Associated with each observation is a response value. Suppose that we wish to predict a test observation’s response using only observations that are within $10\%$ of the range of $X$ closest to that test observation. For instance, in order to predict the response for a test observation with $X = 0.6$, we will use observations in the range $[0.55, 0.65]$. On average, what fraction (分數、數量) of the available (可用的) observations will we use to make the prediction?

# %% [markdown]
# > Ans: 因為均勻分布，所以可用資料平均為 10%

# %% [markdown]
# (b) Now suppose that we have a set of observations, each with measurements on $p = 2$ features, $X_1$ and $X_2$. We assume that $(X_1,X_2)$ are uniformly distributed on $[0, 1] \times [0, 1]$. We wish to predict a test observation’s response using only observations that are within $10\%$ of the range of $X_1$ and within $10\%$ of the range of $X_2$ closest to that test observation. For instance, in order to predict the response for a test observation with $X_1 = 0.6$ and $X_2 = 0.35$, we will use observations in the range $[0.55, 0.65]$ for $X_1$ and in the range $[0.3, 0.4]$ for $X_2$. On average, what fraction of the available observations will we use to make the prediction?

# %% [markdown]
# > Ans: 均勻且各 10%，得到 $\frac{10}{100}\times\frac{10}{100}$ 等於 $0.01=10^{-2}=1\%$

# %% [markdown]
# (c) Now suppose that we have a set of observations on $p = 100$ features.
# Again the observations are uniformly distributed on each feature, and again each feature ranges in value from 0 to 1. We wish to predict a test observation’s response using observations within the $10\%$ of each feature’s range that is closest to that test observation. What fraction of the available observations will we use to make the prediction?

# %% [markdown]
# > Ans: $(10\%)^{100}$

# %%
0.1**100
# Out:
# 1.0000000000000056e-100

# %% [markdown]
# (d) Using your answers to parts (a)–(c), argue (爭辯) that a drawback (缺點) of
# KNN when $p$ is large is that there are very few training observations
# "near" any given test observation.

# %% [markdown]
# > Ans: $lim_{p \to \infty}(\frac{10}{100})^p=0$，p越大，越高維，越沒有鄰居

# %% [markdown]
# Essentially (本質上)，接近一個點意味著在每個維度上都接近<br>
# 在實踐中，潛在分佈不是均勻隨機的，並且具有一定的結構，因此點仍然可以在一定程度上聚集在一起

# %% [markdown]
# (e) Now suppose that we wish to make a prediction for a test observation
# by creating a $p$-dimensional hypercube centered around the test observation that contains, on average, $10\%$ of the training observations. For $p = 1, 2,$ and $100$, what is the length of each side of the hypercube? Comment on your answer.
#
# Note: A hypercube is a generalization of a cube to an arbitrary number of dimensions. When $p = 1$, a hypercube is simply a line segment (段), when $p = 2$ it is a square, and when $p = 100$ it is a $100$-dimensional cube.

# %% [markdown]
# > Ans: x 為每邊邊長，每邊總長為1
#
# - p=1 : $x=10\%\times1=0.1$
#
# - p=2 : $x^2=10\%\times1\times1=0.1$，$x=\sqrt{0.1}\thickapprox0.31$
#
# - p=100 : $x^{100}=10\%\times(1^{100})$，$x=\sqrt[100]{0.1}\thickapprox0.98$ $\;\;$**幾乎用到每個維度的全部觀察值$\leftrightarrow$在某種程度上，高維沒有鄰居**

# %%
0.1**0.5
# Out:
# 0.31622776601683794

# %%
0.1**0.01
# Out:
# 0.9772372209558107

# %% [markdown]
# # 5
# We now examine (檢查) the differences between LDA and QDA (二次判別分析).

# %% [markdown]
# (a) If the Bayes decision boundary is linear, do we expect LDA or
# QDA to perform better on the training set? On the test set?

# %% [markdown]
# > Ans: <br>
# 訓練集上兩個都差不多，<br>
# 測試集上 LDA 勝，QDA 可能會因為過擬合而做出較差的預測<br><br>
# 我們都希望 QDA 在訓練集上的表現優於 LDA。<br>
# 這是因為 QDA 更靈活，可以導致更緊密的擬合。<br>
# 然而，如果貝葉斯決策邊界是線性的，QDA 額外的靈活性會導致過擬合，<br>
# 且預計 LDA 在測試集上的表現優於 QDA

# %% [markdown]
# (b) If the Bayes decision boundary is non-linear, do we expect LDA
# or QDA to perform better on the training set? On the test set?

# %% [markdown]
# > Ans: <br>
# 由於額外的靈活性，我們預計 QDA 在訓練集上的表現優於 LDA<br>
# 如果貝葉斯決策邊界是非線性的，我們預計 QDA 在測試集上的表現也會更好<br><br>
# 因為額外的靈活性允許它至少捕獲一些非線性<br>
# 換句話說，LDA 是有偏差的，導致測試集的性能更差<br>
# QDA 也可能有偏差，取決於決策邊界的非線性性質，但一般情況下會少一些

# %% [markdown]
# (c) In general, as the sample size $n$ increases, do we expect the test
# prediction accuracy of QDA relative to LDA to improve, decline,
# or be unchanged? Why?

# %% [markdown]
# > Ans: <br>
# 在線性和非線性貝葉斯決策邊界的兩種情況下<br>
# 我們預計 QDA 的性能相對於 LDA 會有所提高<br><br>
# 一般來說，如 n 隨著樣本量的增加，方差減小<br>更靈活的模型 (QDA) 的擬合會提高

# %% [markdown]
# (d) True or False: Even if the Bayes decision boundary for a given
# problem is linear, we will probably achieve a superior (優越) test error
# rate using QDA rather than LDA because QDA is flexible
# enough to model a linear decision boundary. Justify your answer.

# %% [markdown]
# > Ans: <br>
# 錯誤的<br><br>
# 對於線性貝葉斯決策邊界<br>QDA 與 LDA 相比過於靈活<br>
# 數據中的噪聲會導致其過擬合<br><br>
# 雖然隨著樣本量的增加，過度擬合會減少<br>
# 但總的來說，我們仍然希望 LDA 更好<br>
# 因為它是無偏的並且不太容易擬合噪聲<br>

# %% [markdown]
# - **一般來說，更靈活的模型具有更少的偏差和更高的方差**
# - **相比之下，更嚴格的模型具有較高的偏差和較低的方差**
#
#
# - 低方差：隨著訓練資料集的變化，對目標函式估計值的變化非常小
# - 高方差：隨著訓練資料集的變化，對目標函式估計值的變化非常大
# - 低偏差：對目標函式提出更少的假設，KNN 和 SVM
# - 高偏差：對目標函式提出更多的假設，線性迴歸和邏輯斯特迴歸
#
# ```
# 非引數化演算法: 較低的偏差
# 對目標函式做出很少或者根本不做任何假設，
# 但是它需要更多的資料，訓練速度非常慢，模型複雜度非常高，但是模型非常強大
#
# 引數化演算法: 較高的偏差
# 使得學習速度非常快，而且非常容易去理解，
# 不需要很多的資料，但是通常不太靈活
# ```
# 具有高偏差和低方差，過擬合問題。<br>
# 它總是取決於偏差-方差的權衡，並且通常取決於訓練集的大小和噪聲的大小。

# %% [markdown]
# ## Applied

# %% [markdown]
# # 14
# In this problem, you will develop a model to predict whether a given
# car gets high or low gas mileage (油耗) based on the  <span style='color:red'>Auto</span> data set.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\統計探勘功課\Auto.csv",index_col='Unnamed: 0')
df.head()

# 路徑字串開頭要寫 r & 檔案名稱.csv                         
# r :為了不讓 \ 被讀成特殊字元 EX: \n
# 指定欄位 id 為索引 (取代原本 0.1...957918的位置)
# ,index_col='id'
# college.index.name = 'Names'
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1  18.0          8         307.0         130    3504          12.0    70
# 2  15.0          8         350.0         165    3693          11.5    70
# 3  18.0          8         318.0         150    3436          11.0    70
# 4  16.0          8         304.0         150    3433          12.0    70
# 5  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 1       1  chevrolet chevelle malibu
# 2       1          buick skylark 320
# 3       1         plymouth satellite
# 4       1              amc rebel sst
# 5       1                ford torino

# %% [markdown]
# (a) Create a binary variable,  <span style='color:red'>mpg01</span>, that contains a 1 if  <span style='color:red'>mpg</span> contains a value above its median, and a 0 if  <span style='color:red'>mpg</span> contains a value below its median. You can compute the median using the  <span style='color:red'>np.median()</span> function.

# %%
np.median(df['mpg'])
# Out:
# 22.75

# %%
df['mpg01']= np.where(df['mpg'] > df['mpg'].median(), 1, 0)

# %% [markdown]
# (b) Explore the data graphically (圖形) in order to investigate the association
# between <span style='color:red'>mpg01</span> and the other features. Which of the other features seem most likely to be useful in predicting <span style='color:red'>mpg01</span>? Scatterplots and boxplots may be useful tools to answer this question. Describe your findings.

# %%
df = df.drop('mpg', axis=1)
df.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  year  origin  \
# 1          8         307.0         130    3504          12.0    70       1
# 2          8         350.0         165    3693          11.5    70       1
# 3          8         318.0         150    3436          11.0    70       1
# 4          8         304.0         150    3433          12.0    70       1
# 5          8         302.0         140    3449          10.5    70       1
#
#                         name  mpg01
# 1  chevrolet chevelle malibu      0
# 2          buick skylark 320      0
# 3         plymouth satellite      0
# 4              amc rebel sst      0
# 5                ford torino      0

# %%
g = sns.PairGrid(df, height=2)
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.fig.set_size_inches(12, 12)

# %% [markdown]
# [seaborn.PairGrid](https://seaborn.pydata.org/generated/seaborn.PairGrid.html)

# %%
# correlation matrix

corrmat_2 = df.corr()      # 'list' object has no attribute 'corr'

f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat_2, square=True,annot=True,cmap = 'YlGnBu_r')

# corrmat_2
# Out:
# <AxesSubplot:>

# %% [markdown]
# 從上面的散點圖和相關矩陣的最後一行，<br>
# 我們看到幾個變量與mpg01高度相關，特別是氣缸、位移和重量

# %%
# cylinders displacement weight

fig = plt.figure()  # To add space between subplots

plt.subplot(131)
sns.boxplot(x='mpg01', y='cylinders', data=df)

plt.subplot(132)
sns.boxplot(x='mpg01', y='displacement', data=df)

plt.subplot(133)
sns.boxplot(x='mpg01', y='weight', data=df)

fig.subplots_adjust(wspace=1) # To add space between subplots

# %% [markdown]
# 由盒鬚圖也證實了 mpg01 能把這幾個變量很好的劃分開來

# %%
# horsepower acceleration year origin

fig = plt.figure()  # To add space between subplots

plt.subplot(141)
sns.boxplot(x='mpg01', y='horsepower', data=df)

plt.subplot(142)
sns.boxplot(x='mpg01', y='acceleration', data=df)

plt.subplot(143)
sns.boxplot(x='mpg01', y='year', data=df)

plt.subplot(144)
sns.boxplot(x='mpg01', y='origin', data=df)

fig.subplots_adjust(wspace=1.5) # To add space between subplots

# %% [markdown]
# 剩下這幾個變量，除了馬力，其他幾乎沒大大影響(相關)

# %% [markdown]
# [matplotlib.pyplot.subplots_adjust](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots_adjust.html)

# %% [markdown]
# (c) Split the data into a training set and a test set.

# %%
from sklearn.model_selection import train_test_split 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

##### (評分指標)
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score

# %%
# cylinders displacement horsepower weight

x = df[['cylinders', 'displacement', 'horsepower', 'weight']].values
y = df['mpg01'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
x
# Out:
# array([[   8.,  307.,  130., 3504.],
#        [   8.,  350.,  165., 3693.],
#        [   8.,  318.,  150., 3436.],
#        ...,
#        [   4.,  135.,   84., 2295.],
#        [   4.,  120.,   79., 2625.],
#        [   4.,  119.,   82., 2720.]])

# %% [markdown]
# (d) Perform (執行) LDA on the training data in order to predict <span style='color:red'>mpg01</span> using the variables that seemed most associated with <span style='color:red'>mpg01</span> in (b). What is the test error of the model obtained?

# %%
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

##### (評分指標)
# from sklearn.metrics import roc_auc_score, confusion_matrix

lda = LinearDiscriminantAnalysis()
lda.fit(x_train, y_train)

accuracy_score(y_test, lda.predict(x_test))
# Out:
# 0.9285714285714286

# %% [markdown]
# [sklearn.discriminant_analysis.LinearDiscriminantAnalysis ](https://scikit-learn.org/stable/modules/generated/sklearn.discriminant_analysis.LinearDiscriminantAnalysis.html)

# %% [markdown]
# (e) Perform QDA on the training data in order to predict <span style='color:red'>mpg01</span> using the variables that seemed most associated with <span style='color:red'>mpg01</span> in (b). What is the test error of the model obtained?

# %%
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

qda = QuadraticDiscriminantAnalysis()
qda.fit(x_train, y_train)

accuracy_score(y_test, qda.predict(x_test))
# Out:
# 0.9387755102040817

# %% [markdown]
# [sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis](https://scikit-learn.org/stable/modules/generated/sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis.html#sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis)

# %% [markdown]
# (f) Perform logistic regression on the training data in order to predict <span style='color:red'>mpg01</span> using the variables that seemed most associated with <span style='color:red'>mpg01</span> in (b). What is the test error of the model obtained?

# %%
# from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train, y_train)

accuracy_score(y_test, lr.predict(x_test))
# Out:
# 0.9183673469387755

# %% [markdown]
# (g) Perform naive Bayes on the training data in order to predict <span style='color:red'>mpg01</span> using the variables that seemed most associated with <span style='color:red'>mpg01</span> in (b). What is the test error of the model obtained?

# %%
# from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
clf.fit(x_train, y_train)

accuracy_score(y_test, lr.predict(x_test))
# Out:
# 0.9183673469387755

# %% [markdown]
# [sklearn.naive_bayes.GaussianNB ](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html)

# %%
from sklearn.neighbors import KNeighborsClassifier

for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_test))
    print('K = {:3}, accuracy = {:.4f}'.format(K, acc))
# Out:
# K =   1, accuracy = 0.8776
# K =   2, accuracy = 0.8571
# K =   3, accuracy = 0.8980
# K =   4, accuracy = 0.8980
# K =   5, accuracy = 0.8673
# K =   6, accuracy = 0.8878
# K =   7, accuracy = 0.8878
# K =   8, accuracy = 0.9082
# K =   9, accuracy = 0.8980
# K =  10, accuracy = 0.8980
# K =  11, accuracy = 0.9082
# K =  12, accuracy = 0.9082
# K =  13, accuracy = 0.9082
# K =  14, accuracy = 0.9082
# K =  15, accuracy = 0.8980
# K =  16, accuracy = 0.8980
# K =  17, accuracy = 0.8878
# K =  18, accuracy = 0.9184
# K =  19, accuracy = 0.9184
# K =  20, accuracy = 0.9184
# K =  21, accuracy = 0.9082
# K =  22, accuracy = 0.9082
# K =  23, accuracy = 0.9082
# K =  24, accuracy = 0.9184
# K =  25, accuracy = 0.9082
# K =  26, accuracy = 0.9184
# K =  27, accuracy = 0.9184
# K =  28, accuracy = 0.9184
# K =  29, accuracy = 0.9184
# K =  30, accuracy = 0.9184
# K =  31, accuracy = 0.9184
# K =  32, accuracy = 0.9184
# K =  33, accuracy = 0.9082
# K =  34, accuracy = 0.9082
# ...

# %%
ins=[]

for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_test))
    ins.append(acc)

plt.plot(np.arange(1,101), ins)

# %% [markdown]
# 上面的結果似乎表明 K 的最佳值在 19 和 30 左右，儘管不同 K 值之間的精度差異不是很大

# %% [markdown]
# [練習 4.11](https://botlnec.github.io/islp/sols/chapter4/exercise11/)

# %% [markdown]
# # 16
# Using the <span style='color:red'>Boston</span> data set, fit classification models in order to predict whether a given census (人口普查) tract (區) has a crime rate above or below the median. Explore logistic regression, LDA, naive Bayes, and KNN models using various subsets of the predictors. Describe your findings.
#
# Hint: You will have to create the response variable yourself, using the variables that are contained in the <span style='color:red'>Boston</span> data set.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston

# %matplotlib inline

# %%
boston = load_boston()
df = pd.DataFrame(boston.data, columns=boston.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ```python
# df = pd.read_csv(r"C:\Users\user\Desktop\Data\Boston.csv",index_col='Unnamed: 0')
# df.head()
#
# # 路徑字串開頭要寫 r & 檔案名稱.csv
# # r :為了不讓 \ 被讀成特殊字元 EX: \n
# # 指定欄位 id 為索引 (取代原本 0.1...957918的位置)
# # ,index_col='id'
# # college.index.name = 'Names'
# ```

# %%
np.median(df['CRIM'])
# Out:
# 0.25651

# %%
df['CRIM01']= np.where(df['CRIM'] > df['CRIM'].median(), 1, 0)

# %%
df = df.drop('CRIM', axis=1)
df.head()
# Out:
#      ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  \
# 0  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90
# 1   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90
# 2   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83
# 3   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63
# 4   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90
#
#    LSTAT  CRIM01
# 0   4.98       0
# 1   9.14       0
# 2   4.03       0
# 3   2.94       0
# 4   5.33       0

# %%
g = sns.PairGrid(df, height=2)
g.map_upper(plt.scatter, s=3)
g.map_diag(plt.hist)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.fig.set_size_inches(12, 12)

# %%
# correlation matrix

corrmat_2 = df.corr()      # 'list' object has no attribute 'corr'

f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat_2, square=True,annot=True,cmap = 'YlGnBu_r')

# corrmat_2
# Out:
# <AxesSubplot:>

# %% [markdown]
# 取 'INDUS','NOX','AGE','DIS','RAD','TAX'

# %%
# cylinders displacement weight

fig = plt.figure()  # To add space between subplots

plt.subplot(231)
sns.boxplot(x='CRIM01', y='INDUS', data=df)

plt.subplot(232)
sns.boxplot(x='CRIM01', y='NOX', data=df)

plt.subplot(233)
sns.boxplot(x='CRIM01', y='AGE', data=df)

plt.subplot(234)
sns.boxplot(x='CRIM01', y='DIS', data=df)

plt.subplot(235)
sns.boxplot(x='CRIM01', y='RAD', data=df)

plt.subplot(236)
sns.boxplot(x='CRIM01', y='TAX', data=df)

fig.subplots_adjust(wspace=1,hspace=1) # To add space between subplots

# %% [markdown]
# # 模型

# %% [markdown]
# ```python
# # from sklearn.model_selection import train_test_split
# # from sklearn.cross_validation import train_test_split
#
# # from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
# # from sklearn.linear_model import LogisticRegression
# # from sklearn.naive_bayes import GaussianNB
# # from sklearn.neighbors import KNeighborsClassifier
#
# ##### (評分指標)
# # from sklearn.metrics import accuracy_score
# ```

# %%
### All variable
x_all = df.iloc[:,:-1].values

### 6 variable
x_6 = df[['INDUS','NOX','AGE','DIS','RAD','TAX']].values

y = df['CRIM01'].values

x_all_train, x_all_test, y_train, y_test = train_test_split(x_all, y, random_state=1)
x_6_train, x_6_test, y_train, y_test = train_test_split(x_6, y, random_state=1)

# %% [markdown]
# ### LDA

# %%
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

##### (評分指標)
# from sklearn.metrics import roc_auc_score, confusion_matrix

lda = LinearDiscriminantAnalysis()

lda.fit(x_6_train, y_train)
print("Accuracy with x_6  :",accuracy_score(y_test, lda.predict(x_6_test)))

lda.fit(x_all_train, y_train)
print("Accuracy with x_all:",accuracy_score(y_test, lda.predict(x_all_test)))
# Out:
# Accuracy with x_6  : 0.8188976377952756
# Accuracy with x_all: 0.8346456692913385

# %% [markdown]
# ### QDA

# %%
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

qda = QuadraticDiscriminantAnalysis()

qda.fit(x_6_train, y_train)
print("Accuracy with x_6  :",accuracy_score(y_test, qda.predict(x_6_test)))

qda.fit(x_all_train, y_train)
print("Accuracy with x_all:",accuracy_score(y_test, qda.predict(x_all_test)))
# Out:
# Accuracy with x_6  : 0.8740157480314961
# Accuracy with x_all: 0.905511811023622

# %% [markdown]
# ### Logistic

# %%
# from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(x_6_train, y_train)
print("Accuracy with x_6  :",accuracy_score(y_test, lr.predict(x_6_test)))

lr.fit(x_all_train, y_train)
print("Accuracy with x_all:",accuracy_score(y_test, lr.predict(x_all_test)))
# Out:
# Accuracy with x_6  : 0.8188976377952756
# Accuracy with x_all: 0.8503937007874016
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# ### Naive_bayes

# %%
# from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()

clf.fit(x_6_train, y_train)
print("Accuracy with x_6  :",accuracy_score(y_test, clf.predict(x_6_test)))

clf.fit(x_all_train, y_train)
print("Accuracy with x_all:",accuracy_score(y_test, clf.predict(x_all_test)))
# Out:
# Accuracy with x_6  : 0.8110236220472441
# Accuracy with x_all: 0.7952755905511811

# %% [markdown]
# ### KNN

# %%
best_acc = 0
best_k = 0
for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_all_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_all_test))
    if acc > best_acc:
        best_acc, best_k = acc, K

print('Best accuracy = {:.4f} with K = {:3}'.format(best_acc, best_k))
# Out:
# Best accuracy = 0.9370 with K =   1

# %%
best_acc = 0
best_k = 0
for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_6_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_6_test))
    if acc > best_acc:
        best_acc, best_k = acc, K

print('Best accuracy = {:.4f} with K = {:3}'.format(best_acc, best_k))
# Out:
# Best accuracy = 0.9370 with K =   1

# %%
# from sklearn.neighbors import KNeighborsClassifier

for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_all_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_all_test))
    print('K = {:3}, accuracy = {:.4f}'.format(K, acc))
# Out:
# K =   1, accuracy = 0.9370
# K =   2, accuracy = 0.9291
# K =   3, accuracy = 0.9213
# K =   4, accuracy = 0.9213
# K =   5, accuracy = 0.9213
# K =   6, accuracy = 0.9134
# K =   7, accuracy = 0.8898
# K =   8, accuracy = 0.8819
# K =   9, accuracy = 0.8976
# K =  10, accuracy = 0.8898
# K =  11, accuracy = 0.8740
# K =  12, accuracy = 0.8425
# K =  13, accuracy = 0.8583
# K =  14, accuracy = 0.8268
# K =  15, accuracy = 0.8346
# K =  16, accuracy = 0.8268
# K =  17, accuracy = 0.8346
# K =  18, accuracy = 0.8268
# K =  19, accuracy = 0.8268
# K =  20, accuracy = 0.8268
# K =  21, accuracy = 0.8110
# K =  22, accuracy = 0.8189
# K =  23, accuracy = 0.8189
# K =  24, accuracy = 0.8189
# K =  25, accuracy = 0.8189
# K =  26, accuracy = 0.8189
# K =  27, accuracy = 0.8268
# K =  28, accuracy = 0.8268
# K =  29, accuracy = 0.8268
# K =  30, accuracy = 0.8268
# K =  31, accuracy = 0.8189
# K =  32, accuracy = 0.8189
# K =  33, accuracy = 0.8189
# K =  34, accuracy = 0.8189
# ...

# %%
ins=[]

for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_all_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_all_test))
    ins.append(acc)

plt.plot(np.arange(1,101), ins)

# %%
# from sklearn.neighbors import KNeighborsClassifier

for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_6_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_6_test))
    print('K = {:3}, accuracy = {:.4f}'.format(K, acc))
# Out:
# K =   1, accuracy = 0.9370
# K =   2, accuracy = 0.9213
# K =   3, accuracy = 0.9213
# K =   4, accuracy = 0.9134
# K =   5, accuracy = 0.9055
# K =   6, accuracy = 0.9134
# K =   7, accuracy = 0.8819
# K =   8, accuracy = 0.8819
# K =   9, accuracy = 0.8819
# K =  10, accuracy = 0.8740
# K =  11, accuracy = 0.8819
# K =  12, accuracy = 0.8819
# K =  13, accuracy = 0.8819
# K =  14, accuracy = 0.8583
# K =  15, accuracy = 0.8583
# K =  16, accuracy = 0.8425
# K =  17, accuracy = 0.8346
# K =  18, accuracy = 0.8425
# K =  19, accuracy = 0.8189
# K =  20, accuracy = 0.8189
# K =  21, accuracy = 0.8189
# K =  22, accuracy = 0.8189
# K =  23, accuracy = 0.8189
# K =  24, accuracy = 0.8189
# K =  25, accuracy = 0.8189
# K =  26, accuracy = 0.8189
# K =  27, accuracy = 0.8189
# K =  28, accuracy = 0.8189
# K =  29, accuracy = 0.8110
# K =  30, accuracy = 0.8110
# K =  31, accuracy = 0.8110
# K =  32, accuracy = 0.8110
# K =  33, accuracy = 0.8110
# K =  34, accuracy = 0.8110
# ...

# %%
ins=[]

for K in range(1,101):
    knn = KNeighborsClassifier(n_neighbors=K)
    knn.fit(x_6_train, y_train)
    acc = accuracy_score(y_test, knn.predict(x_6_test))
    ins.append(acc)

plt.plot(np.arange(1,101), ins)

# %% [markdown]
# ```
# 使用了預測變量的兩個子集：
# 所有這些子集 & 與響應最相關的 6 個
# 從上面的結果中，我們可以看到，
# 包含所有預測變量會提高準確率（KNN、NB 除外），但提高幅度不大
#
# QDA 比 LDA 具有更好的精度(測試集)，表明非線性貝葉斯決策邊界
#
# 最好的模型是 KNN，K = 1
# ```

# %% [markdown]
# [練習 4.13](https://botlnec.github.io/islp/sols/chapter4/exercise13/)
#
# 為了更穩健的分析，我們應該執行交叉驗證。我們將帶到下一章
