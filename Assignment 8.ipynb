# %% [markdown]
# # Chapter 8 - Tree-Based Methods

# %% [markdown]
# #### Student ID:B082040005
#
# #### Name:高念慈

# %% [markdown]
# ### Q1:
# #### For the following pair of figures, where the left figure is a partition of two dimensional feature space and the right one is a decision tree, write down the correct regions $R_1, R_2, \dots, R_6$ for the (a) to (f), cutpoints $t_1$ and $t_5$ for (g) and (h), and criteria for (i), (j), and (k).

# %% [markdown]
# &nbsp;&nbsp;$10$&nbsp;|---------------|-------------------------|---------------|
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|&emsp;&nbsp;&nbsp;(a)&emsp;&nbsp;&nbsp;|  &emsp;&emsp;&emsp;$X_1 \leq t_1$
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&nbsp;|  &emsp;&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&nbsp;(i)
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;(g)&nbsp;|---------------|  &emsp;&emsp;|----------|----------|
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&nbsp;&nbsp;&nbsp;(b)&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&nbsp;|  &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;&nbsp;|
# &emsp;&emsp;|&emsp;&nbsp;&nbsp;(c)&emsp;&nbsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&nbsp;|  &emsp;&emsp;|&emsp;&emsp;&nbsp;&nbsp;&nbsp;(j)&emsp;&emsp;|&emsp;&nbsp;&nbsp;&nbsp;(k)
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|&emsp;&nbsp;$R_6$&emsp;&nbsp;&nbsp;|  &emsp;&emsp;|&emsp;&emsp;&emsp;|---------|--------|
# $X_2$&nbsp;&nbsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&nbsp;|  &emsp;&emsp;|&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;&nbsp;|&emsp;$X_2 \geq t_5$
# &emsp;&emsp;|&emsp;&emsp;&emsp;$t_2$|---------------|----------|---------------|  &emsp;&emsp;|&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&nbsp;|-----|-----|
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&nbsp;&nbsp;&nbsp;$t_3$&emsp;&emsp;&emsp;&nbsp;&nbsp;|  &emsp;&emsp;|&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&nbsp;|&emsp;&emsp;&emsp;|
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;$R_2$&emsp;&nbsp;&nbsp;|&emsp;&emsp;&emsp;(d)&emsp;&emsp;&emsp;|  &emsp;&emsp;|&emsp;&emsp;|---|---|&emsp;&emsp;&nbsp;|&emsp;&emsp;|---|---|
# &emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;|&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;|  &emsp;&emsp;|&emsp;&emsp;|&emsp;&emsp;|&emsp;&emsp;|&emsp;&emsp;|&emsp;&emsp;|
# &emsp;$0$&nbsp;|---------------|---------------|--------------------------|  &emsp;&nbsp;&nbsp;$R_1$&nbsp;&nbsp;&nbsp;(e)&emsp;$R_3$&nbsp;&nbsp;&nbsp;$R_4$&emsp;$R_5$&nbsp;&nbsp;&nbsp;(f)
# &emsp;&nbsp;&nbsp;&nbsp;$0$&emsp;&emsp;&emsp;&nbsp;&nbsp;(h)&emsp;&nbsp;&emsp;&emsp;&nbsp;$t_4$&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;$10$
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;$X_1$
# &emsp;

# %% [markdown]
# > Ans:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q2:
# #### Consider the Gini index, classification error, and entropy in a simple classification setting with two classes. Create a single plot that displays each of these quantities as a function of $p$. The x-axis should display $p$, ranging from $0$ to $1$, and the y-axis should display the value of the Gini index, classification error, and entropy.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

p = np.linspace(.001,.999,100)
gini = p * (1 - p) * 2                                # ___________Gini index___________
classerr = 1 - np.max([p, 1-p], axis=0)               # ______classification error______
entropy = -(p * np.log(p) + (1 - p) * np.log(1 - p))  # _____________entropy_____________

fig, ax = plt.subplots()
sns.lineplot(x=p, y=gini, color = 'red')
sns.lineplot(x=p, y=classerr, color = 'green')
sns.lineplot(x=p, y=entropy, color = 'blue')
ax.set_xlabel('p')
ax.legend(['Gini index', 'classification error', 'entropy'])
plt.show()

# %% [markdown]
# ### Q3:
# #### Suppose we produce ten bootstrapped samples from a data set containing red and green classes. We then apply a classification tree to each bootstrapped sample and, for a specific value of $X$, produce 10 estimates of probability $P(\text{Class is Red}|X)$:
#
# #### $$
# 0.1, 0.15, 0.2, 0.2, 0.55, 0.6, 0.6, 0.65, 0.7, \text{and}\ 0.75.
# $$
#
# #### There are two common ways to combine these results together into a single class prediction. One is the majority vote approach discussed in this chapter. The second approach is to classify based on the average probability. In this example, what is the final probability $P(\text{Class is Red}|X)$ under each of these two approaches? What is the final classification under each of these two approaches?

# %% [markdown]
# > Ans:
# If we look at majority vote approach,<br>
# then 6 out of 10 probabilities have P(Class is Red|X) > 0.5,<br>
# hence in this case the value of P(Class is Red|X) will be 0.6.<br>
# The class predicted is Red class.<br><br>
# For the average probability,<br>
# we will take the average of all the probabilities here which will be 0.45,<br>
# hence the class predicted in this case will be Green class.

# %%
x =(0.1,0.15,0.2,0.2,0.55,0.6,0.6,0.65,0.7, 0.75)
np.mean(x)
# Out:
# 0.45

# %% [markdown]
# ### Q4:
# #### In the lab, a classification tree was applied to the `Carseats` data set after converting `Sales` into a qualitative response variable. Now we will seek to predict `Sales` using regression trees and related approaches, treating the response as a quantitative variable. With the data split into a training set and a test set.

# %%
# Run this block if you're using Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

path = r"C:\Users\user\Desktop\Data\Carseats.csv"
Carseats = pd.read_csv(path)
Carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
from sklearn.model_selection import train_test_split

data = Carseats.copy()
data['Urban'] = data['Urban'].map({'No':0, 'Yes':1,})
data['US'] = data['US'].map({'No':0, 'Yes':1})
data['ShelveLoc'] = data['ShelveLoc'].map({'Bad':0, 'Medium':5, 'Good':10})

X_train, X_test, y_train, y_test = train_test_split(data.drop('Sales',axis= 1),data['Sales'], test_size = 0.5, random_state = 42)

# %% [markdown]
# #### (a) Fit a regression tree with `random_state = 42` to the training set. Obtain the train MSE, plot the tree, and interpret both results. Report the test MSE you obtain.

# %%
# pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import plot_tree, export_graphviz
import graphviz

# ______regression tree______ 
reg_tree =  DecisionTreeRegressor(random_state=42)
reg_tree.fit(X_train, y_train)

# _______training mse_______
train_mse = mean_squared_error(y_train, reg_tree.predict(X_train))

# _________plot tree_________
plt.figure(figsize=(40,24))
plot_tree(reg_tree, feature_names=X_train.columns,  
                    class_names=['No','Yes'],
                    filled=True)
plt.show()

print('Training MSE is ', train_mse)
# Out:
# Training MSE is  0.0

# %%
len(np.unique(y_train))
# Out:
# 186

# %% [markdown]
# > Ans:  <br>
# train MSE = 0 : 可以看到他過擬合了<br>
# 對樹沒其他的限制下，樹會分支到每個葉都只剩一個樣本點，過擬合<br>
# test MSE = 6.566900499999999 : 明顯跟 train MSE 差很多

# %%
# ________test mse________
test_mse = mean_squared_error(y_test, reg_tree.predict(X_test))
print('Testing MSE is ', test_mse)
# Out:
# Testing MSE is  6.566900499999999

# %% [markdown]
# #### (b) Use 10-fold cross-validation in order to determine the optimal level of tree complexity (`max_leaf_nodes`). Does pruning the tree improve the test MSE?
# (Set random_state for both k-fold and regression tree to 42)

# %%
from sklearn.model_selection import KFold, cross_val_score

tree_sizes = range(2, 50)
scores = []

# ______k-fold______
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# 10-Fold CV for each tree size 
for tree_size in tree_sizes:
    # ______regression tree______
    reg_tree = DecisionTreeRegressor(max_leaf_nodes=tree_size, random_state=42)
    
    # _______training mse_______
    train_mse = -np.mean(cross_val_score(reg_tree, X_train, y_train, cv=kf, scoring='neg_mean_squared_error'))
    scores.append(train_mse)

fig, ax = plt.subplots(figsize=(6, 4))
plt.plot(range(2, 50), scores)
plt.plot(scores.index(min(scores))+2, min(scores), marker = 'o', c='r')
ax.text(scores.index(min(scores))+2, min(scores)+0.1, scores.index(min(scores))+2, size=12)
plt.xlim(2,50)
plt.xticks(range(2, 50, 6))
plt.xlabel('Max Leaf Nodes')
plt.ylabel('10-Fold training MSE')
# Out:
# Text(0, 0.5, '10-Fold training MSE')

# %%
scores.index(min(scores))
# Out:
# 11

# %%
# ______regression tree with best max leaf nodes______
reg_tree = DecisionTreeRegressor(max_leaf_nodes=13, random_state=42)

reg_tree.fit(X_train, y_train)

# ________test mse________
test_mse = mean_squared_error(y_test, reg_tree.predict(X_test))
print('Test MSE is ', test_mse)
# Out:
# Test MSE is  5.662771063039613

# %% [markdown]
# > Ans:
# yes，Test MSE has decreases from 6.566900499999999 to 5.662771063039613

# %% [markdown]
# ---
